# %% [markdown]
# ## Song Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data 
df = pd.read_csv('../data/complete_playlist_data.csv')
df.shape
# Out:
# (1897, 22)

# %%
df.head()
# Out:
#                            name  \
# 0     Ehsaan Tera Hoga Mujh Par
# 1  Chahe Mujhe Koi Junglee Kahe
# 2         Mera Saaya Saath Hoga
# 3               Jhoomka Gira Re
# 4           Lag Ja Gale Se Phir
#
#                                                album           artist  \
# 0       Junglee (Original Motion Picture Soundtrack)  Various Artists
# 1       Junglee (Original Motion Picture Soundtrack)  Various Artists
# 2    Mera Saaya (Original Motion Picture Soundtrack)      Madan Mohan
# 3    Mera Saaya (Original Motion Picture Soundtrack)      Madan Mohan
# 4  Woh Kaun Thi? (Original Motion Picture Soundtr...      Madan Mohan
#
#   release_date   length  popularity  key  danceability  acousticness  \
# 0   2014-01-28  208.986          11    4         0.380         0.985
# 1   2014-01-28  213.720          12    3         0.485         0.925
# 2   1966-12-01  363.200          12    2         0.557         0.982
# 3   1966-12-01  296.825          13    8         0.598         0.901
# 4   2013-11-01  257.613          37    8         0.312         0.796
#
#    danceability.1  ...  liveness  loudness  speechiness    tempo  valence  \
# 0           0.380  ...     0.151    -7.241       0.0419  175.505    0.490
# 1           0.485  ...     0.110    -6.312       0.0736  147.565    0.803
# 2           0.557  ...     0.229   -10.230       0.0285   95.235    0.583
# 3           0.598  ...     0.812    -4.920       0.1600   93.159    0.964
# 4           0.312  ...     0.286   -11.872       0.0391  132.485    0.391
#
#    time_signature  mode             playlist_id  year decade
# 0               4     1  6mx7rVYF6ed2JTMegQ8SY0  2014   2010
# 1               4     1  6mx7rVYF6ed2JTMegQ8SY0  2014   2010
# 2               4     1  6mx7rVYF6ed2JTMegQ8SY0  1966   1960
# 3               4     1  6mx7rVYF6ed2JTMegQ8SY0  1966   1960
# 4               3     1  6mx7rVYF6ed2JTMegQ8SY0  2013   2010
#
# [5 rows x 22 columns]

# %%
# Check the data types
df.dtypes
# Out:
# name                 object
# album                object
# artist               object
# release_date         object
# length              float64
# popularity            int64
# key                   int64
# danceability        float64
# acousticness        float64
# danceability.1      float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# time_signature        int64
# mode                  int64
# playlist_id          object
# year                  int64
# decade                int64
# dtype: object

# %%
# Convert the datetime format
df['release_date'] = pd.to_datetime(df['release_date'], dayfirst=True, errors = 'coerce')
df
# Out:
#                                                 name  \
# 0                          Ehsaan Tera Hoga Mujh Par
# 1                       Chahe Mujhe Koi Junglee Kahe
# 2                              Mera Saaya Saath Hoga
# 3                                    Jhoomka Gira Re
# 4                                Lag Ja Gale Se Phir
# ...                                              ...
# 1892  Pyar Do Pyar Lo - Janbaaz / Soundtrack Version
# 1893                                     Dance Dance
# 1894                               Aap Ke Aa Jane Se
# 1895                     Yeh Mera Dil Yaar Ka Diwana
# 1896                                       Hawa Hawa
#
#                                                   album            artist  \
# 0          Junglee (Original Motion Picture Soundtrack)   Various Artists
# 1          Junglee (Original Motion Picture Soundtrack)   Various Artists
# 2       Mera Saaya (Original Motion Picture Soundtrack)       Madan Mohan
# 3       Mera Saaya (Original Motion Picture Soundtrack)       Madan Mohan
# 4     Woh Kaun Thi? (Original Motion Picture Soundtr...       Madan Mohan
# ...                                                 ...               ...
# 1892                                            Janbaaz   Various Artists
# 1893  Kasam Paida Karnewale Ki (Original Motion Pict...      Bappi Lahiri
# 1894      Khudgarz (Original Motion Picture Soundtrack)     Rajesh Roshan
# 1895           Don (Original Motion Picture Soundtrack)  Kalyanji-Anandji
# 1896                             Hawa Hawa & Other Hits   Hassan Jahangir
#
#      release_date   length  popularity  key  danceability  acousticness  \
# 0      2014-01-28  208.986          11    4         0.380         0.985
# 1      2014-01-28  213.720          12    3         0.485         0.925
# 2      1966-12-01  363.200          12    2         0.557         0.982
# 3      1966-12-01  296.825          13    8         0.598         0.901
# 4      2013-11-01  257.613          37    8         0.312         0.796
# ...           ...      ...         ...  ...           ...           ...
# 1892   1986-01-01  332.293          34   11         0.460         0.357
# 1893   1984-11-23  339.304          21    7         0.604         0.173
# 1894   1987-08-19  432.293          45    1         0.648         0.170
# 1895   1977-12-30  253.773          34    7         0.497         0.830
# 1896   2017-10-02  369.669          44    9         0.575         0.140
#
#       danceability.1  ...  liveness  loudness  speechiness    tempo  valence  \
# 0              0.380  ...     0.151    -7.241       0.0419  175.505    0.490
# 1              0.485  ...     0.110    -6.312       0.0736  147.565    0.803
# 2              0.557  ...     0.229   -10.230       0.0285   95.235    0.583
# 3              0.598  ...     0.812    -4.920       0.1600   93.159    0.964
# 4              0.312  ...     0.286   -11.872       0.0391  132.485    0.391
# ...              ...  ...       ...       ...          ...      ...      ...
# 1892           0.460  ...     0.146    -8.898       0.2980  127.471    0.646
# 1893           0.604  ...     0.115   -12.944       0.1990  165.033    0.384
# 1894           0.648  ...     0.159    -9.185       0.1500  123.614    0.678
# 1895           0.497  ...     0.332   -11.248       0.0624  141.460    0.521
# 1896           0.575  ...     0.324   -13.064       0.1870  125.871    0.914
#
#       time_signature  mode             playlist_id  year decade
# 0                  4     1  6mx7rVYF6ed2JTMegQ8SY0  2014   2010
# 1                  4     1  6mx7rVYF6ed2JTMegQ8SY0  2014   2010
# 2                  4     1  6mx7rVYF6ed2JTMegQ8SY0  1966   1960
# 3                  4     1  6mx7rVYF6ed2JTMegQ8SY0  1966   1960
# 4                  3     1  6mx7rVYF6ed2JTMegQ8SY0  2013   2010
# ...              ...   ...                     ...   ...    ...
# 1892               4     0  4PS7niVvIybq4KFGLDcy6D  1986   1980
# 1893               4     1  4PS7niVvIybq4KFGLDcy6D  1984   1980
# 1894               4     0  4PS7niVvIybq4KFGLDcy6D  1987   1980
# 1895               4     0  4PS7niVvIybq4KFGLDcy6D  1977   1970
# 1896               4     0  4PS7niVvIybq4KFGLDcy6D  2017   2010
#
# [1897 rows x 22 columns]

# %%
# Check the number of songs in each category 
df['decade'].value_counts().sort_index(ascending=True)
# Out:
# 1940      2
# 1950      8
# 1960    247
# 1970    166
# 1980    220
# 1990    283
# 2000    453
# 2010    365
# 2020    153
# Name: decade, dtype: int64

# %% [markdown]
# There is very little data for 1950s and 1940s so we can remove that from the data.

# %%
# Remove the decades 1950 and 1940 from the data 
df = df[(df['decade'] != 1940) & (df['decade'] != 1950)]
df.shape
# Out:
# (1887, 22)

# %%
# Plot the decade wise song counts 
df['decade'].value_counts().sort_index(ascending=True).plot(kind='bar', )
# Out:
# <AxesSubplot:>

# %%
# Create a dataframe with the decade wise data
decade_wise_data = (
    df.groupby(["decade"])
    .agg(
        {
            "danceability": "mean",
            "acousticness": "mean",
            "energy": "mean",
            "loudness": "mean",
            "speechiness": "mean",
            "valence": "mean",
            "tempo": "mean",
            "time_signature": "mean",
            "mode": "mean",
            "length": "mean",
        }
    )
    .reset_index()
)
decade_wise_data
# Out:
#    decade  danceability  acousticness    energy   loudness  speechiness  \
# 0    1960      0.470332      0.895984  0.472692 -10.237000     0.070979
# 1    1970      0.448536      0.800000  0.519331  -9.829169     0.100990
# 2    1980      0.503118      0.649983  0.565470  -9.837691     0.069704
# 3    1990      0.576640      0.481292  0.595647 -11.064389     0.058888
# 4    2000      0.649448      0.305977  0.681386  -7.980609     0.072127
# 5    2010      0.611874      0.396002  0.666252  -7.487499     0.070099
# 6    2020      0.626209      0.482247  0.555000  -7.958405     0.065522
#
#     valence       tempo  time_signature      mode      length
# 0  0.653656  111.418239        3.797571  0.688259  277.103194
# 1  0.581602  110.961289        3.795181  0.644578  357.484440
# 2  0.621176  115.179477        3.895455  0.572727  345.070123
# 3  0.680965  117.650095        3.911661  0.494700  353.614187
# 4  0.632962  115.015132        3.969095  0.615894  321.348768
# 5  0.621488  116.847077        3.882192  0.594521  288.978055
# 6  0.455584  114.275778        3.882353  0.705882  219.499621

# %%
# Save the decade wise charachterstics 
decade_wise_data.to_csv('../data/decade_wise_song_features.csv', index=False)

# %% [markdown]
# ## Data Visualisation of the audio features

# %% [markdown]
# ## Cluster Analysis

# %%
# Import libraries 
from sklearn.metrics.pairwise import pairwise_distances
from scipy.spatial.distance import pdist, squareform

# %%
# Create a similarity matrix using ecludian distance
similarity_matrix = pairwise_distances(decade_wise_data.iloc[:, 1:], metric='euclidean')

# Plot the similarity matrix for averages
plt.figure(figsize=(12, 10))
sns.heatmap(similarity_matrix, 
            cmap='RdBu_r', 
            annot=True, 
            xticklabels=decade_wise_data['decade'], 
            yticklabels=decade_wise_data['decade'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Lower the value, higher the similarity in the matrix.

# %%
# Create a similarity matrix using cosine similarity
similarity_matrix = pairwise_distances(decade_wise_data.iloc[:, 1:], metric='cosine')*1000

# Plot the similarity matrix for averages
plt.figure(figsize=(12, 10))
sns.heatmap(similarity_matrix, 
            cmap='RdBu_r', 
            annot=True, 
            xticklabels=decade_wise_data['decade'], 
            yticklabels=decade_wise_data['decade'])
# Out:
# <AxesSubplot:>

# %%
# Create a similarity matrix using manhattan distance
similarity_matrix = pairwise_distances(decade_wise_data.iloc[:, 1:], metric='manhattan')

# Plot the similarity matrix for averages
plt.figure(figsize=(12, 10))
sns.heatmap(similarity_matrix, 
            cmap='RdBu_r', 
            annot=True, 
            xticklabels=decade_wise_data['decade'], 
            yticklabels=decade_wise_data['decade'])
# Out:
# <AxesSubplot:>

# %%
# Out:
# 1497

# %% [markdown]
# ### Build a UMAP for clustering

# %%
# Import umap library
import umap.umap_ as umap

# Build the UMAP model for decade-wise data 
umap_reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean')
umap_embedding = umap_reducer.fit_transform(decade_wise_data.iloc[:, 1:])

# Plot UMAP embedding
plt.figure(figsize=(12, 10))
sns.scatterplot(umap_embedding[:, 0], umap_embedding[:, 1], hue=decade_wise_data['decade'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('UMAP Embeddings for all songs.')
# Out:
# c:\Users\91981\AppData\Local\Programs\Python\Python38\lib\site-packages\umap\umap_.py:2344: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(
# c:\Users\91981\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'UMAP Embedding')

# %%
df.iloc[:, 7:17]
# Out:
#       danceability  acousticness  danceability.1  energy  instrumentalness  \
# 0            0.380         0.985           0.380   0.389          0.000602
# 1            0.485         0.925           0.485   0.847          0.000000
# 2            0.557         0.982           0.557   0.422          0.100000
# 3            0.598         0.901           0.598   0.787          0.000191
# 4            0.312         0.796           0.312   0.452          0.000874
# ...            ...           ...             ...     ...               ...
# 1892         0.460         0.357           0.460   0.874          0.000805
# 1893         0.604         0.173           0.604   0.637          0.000370
# 1894         0.648         0.170           0.648   0.569          0.000089
# 1895         0.497         0.830           0.497   0.476          0.018400
# 1896         0.575         0.140           0.575   0.532          0.000000
#
#       liveness  loudness  speechiness    tempo  valence
# 0        0.151    -7.241       0.0419  175.505    0.490
# 1        0.110    -6.312       0.0736  147.565    0.803
# 2        0.229   -10.230       0.0285   95.235    0.583
# 3        0.812    -4.920       0.1600   93.159    0.964
# 4        0.286   -11.872       0.0391  132.485    0.391
# ...        ...       ...          ...      ...      ...
# 1892     0.146    -8.898       0.2980  127.471    0.646
# 1893     0.115   -12.944       0.1990  165.033    0.384
# 1894     0.159    -9.185       0.1500  123.614    0.678
# 1895     0.332   -11.248       0.0624  141.460    0.521
# 1896     0.324   -13.064       0.1870  125.871    0.914
#
# [1887 rows x 10 columns]
