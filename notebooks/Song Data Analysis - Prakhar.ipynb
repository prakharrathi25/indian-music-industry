# %% [markdown]
# ## Song Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data 
df = pd.read_csv('../data/complete_playlist_data.csv')
df.shape
# Out:
# (1897, 22)

# %%
df.head()
# Out:
#                            name  \
# 0     Ehsaan Tera Hoga Mujh Par
# 1  Chahe Mujhe Koi Junglee Kahe
# 2         Mera Saaya Saath Hoga
# 3               Jhoomka Gira Re
# 4           Lag Ja Gale Se Phir
#
#                                                album           artist  \
# 0       Junglee (Original Motion Picture Soundtrack)  Various Artists
# 1       Junglee (Original Motion Picture Soundtrack)  Various Artists
# 2    Mera Saaya (Original Motion Picture Soundtrack)      Madan Mohan
# 3    Mera Saaya (Original Motion Picture Soundtrack)      Madan Mohan
# 4  Woh Kaun Thi? (Original Motion Picture Soundtr...      Madan Mohan
#
#   release_date  length  popularity  key  danceability  acousticness  \
# 0   2014-01-28  208986          11    4         0.380         0.985
# 1   2014-01-28  213720          12    3         0.485         0.925
# 2   1966-12-01  363200          12    2         0.557         0.982
# 3   1966-12-01  296825          13    8         0.598         0.901
# 4   2013-11-01  257613          37    8         0.312         0.796
#
#    danceability.1  ...  liveness  loudness  speechiness    tempo  valence  \
# 0           0.380  ...     0.151    -7.241       0.0419  175.505    0.490
# 1           0.485  ...     0.110    -6.312       0.0736  147.565    0.803
# 2           0.557  ...     0.229   -10.230       0.0285   95.235    0.583
# 3           0.598  ...     0.812    -4.920       0.1600   93.159    0.964
# 4           0.312  ...     0.286   -11.872       0.0391  132.485    0.391
#
#    time_signature  mode             playlist_id    year  decade
# 0               4     1  6mx7rVYF6ed2JTMegQ8SY0  2014.0  2010.0
# 1               4     1  6mx7rVYF6ed2JTMegQ8SY0  2014.0  2010.0
# 2               4     1  6mx7rVYF6ed2JTMegQ8SY0  1966.0  1960.0
# 3               4     1  6mx7rVYF6ed2JTMegQ8SY0  1966.0  1960.0
# 4               3     1  6mx7rVYF6ed2JTMegQ8SY0  2013.0  2010.0
#
# [5 rows x 22 columns]

# %%
# Check the data types
df.dtypes
# Out:
# name                 object
# album                object
# artist               object
# release_date         object
# length                int64
# popularity            int64
# key                   int64
# danceability        float64
# acousticness        float64
# danceability.1      float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# time_signature        int64
# mode                  int64
# playlist_id          object
# year                float64
# decade              float64
# dtype: object

# %%
# Convert the datetime format
df['release_date'] = pd.to_datetime(df['release_date'], dayfirst=True, errors = 'coerce')
df
# Out:
#                                                 name  \
# 0                          Ehsaan Tera Hoga Mujh Par
# 1                       Chahe Mujhe Koi Junglee Kahe
# 2                              Mera Saaya Saath Hoga
# 3                                    Jhoomka Gira Re
# 4                                Lag Ja Gale Se Phir
# ...                                              ...
# 1892  Pyar Do Pyar Lo - Janbaaz / Soundtrack Version
# 1893                                     Dance Dance
# 1894                               Aap Ke Aa Jane Se
# 1895                     Yeh Mera Dil Yaar Ka Diwana
# 1896                                       Hawa Hawa
#
#                                                   album            artist  \
# 0          Junglee (Original Motion Picture Soundtrack)   Various Artists
# 1          Junglee (Original Motion Picture Soundtrack)   Various Artists
# 2       Mera Saaya (Original Motion Picture Soundtrack)       Madan Mohan
# 3       Mera Saaya (Original Motion Picture Soundtrack)       Madan Mohan
# 4     Woh Kaun Thi? (Original Motion Picture Soundtr...       Madan Mohan
# ...                                                 ...               ...
# 1892                                            Janbaaz   Various Artists
# 1893  Kasam Paida Karnewale Ki (Original Motion Pict...      Bappi Lahiri
# 1894      Khudgarz (Original Motion Picture Soundtrack)     Rajesh Roshan
# 1895           Don (Original Motion Picture Soundtrack)  Kalyanji-Anandji
# 1896                             Hawa Hawa & Other Hits   Hassan Jahangir
#
#      release_date  length  popularity  key  danceability  acousticness  \
# 0      2014-01-28  208986          11    4         0.380         0.985
# 1      2014-01-28  213720          12    3         0.485         0.925
# 2      1966-12-01  363200          12    2         0.557         0.982
# 3      1966-12-01  296825          13    8         0.598         0.901
# 4      2013-11-01  257613          37    8         0.312         0.796
# ...           ...     ...         ...  ...           ...           ...
# 1892   1986-01-01  332293          34   11         0.460         0.357
# 1893   1984-11-23  339304          21    7         0.604         0.173
# 1894   1987-08-19  432293          45    1         0.648         0.170
# 1895   1977-12-30  253773          34    7         0.497         0.830
# 1896   2017-10-02  369669          44    9         0.575         0.140
#
#       danceability.1  ...  liveness  loudness  speechiness    tempo  valence  \
# 0              0.380  ...     0.151    -7.241       0.0419  175.505    0.490
# 1              0.485  ...     0.110    -6.312       0.0736  147.565    0.803
# 2              0.557  ...     0.229   -10.230       0.0285   95.235    0.583
# 3              0.598  ...     0.812    -4.920       0.1600   93.159    0.964
# 4              0.312  ...     0.286   -11.872       0.0391  132.485    0.391
# ...              ...  ...       ...       ...          ...      ...      ...
# 1892           0.460  ...     0.146    -8.898       0.2980  127.471    0.646
# 1893           0.604  ...     0.115   -12.944       0.1990  165.033    0.384
# 1894           0.648  ...     0.159    -9.185       0.1500  123.614    0.678
# 1895           0.497  ...     0.332   -11.248       0.0624  141.460    0.521
# 1896           0.575  ...     0.324   -13.064       0.1870  125.871    0.914
#
#       time_signature  mode             playlist_id    year  decade
# 0                  4     1  6mx7rVYF6ed2JTMegQ8SY0  2014.0  2010.0
# 1                  4     1  6mx7rVYF6ed2JTMegQ8SY0  2014.0  2010.0
# 2                  4     1  6mx7rVYF6ed2JTMegQ8SY0  1966.0  1960.0
# 3                  4     1  6mx7rVYF6ed2JTMegQ8SY0  1966.0  1960.0
# 4                  3     1  6mx7rVYF6ed2JTMegQ8SY0  2013.0  2010.0
# ...              ...   ...                     ...     ...     ...
# 1892               4     0  4PS7niVvIybq4KFGLDcy6D  1986.0  1980.0
# 1893               4     1  4PS7niVvIybq4KFGLDcy6D  1984.0  1980.0
# 1894               4     0  4PS7niVvIybq4KFGLDcy6D  1987.0  1980.0
# 1895               4     0  4PS7niVvIybq4KFGLDcy6D  1977.0  1970.0
# 1896               4     0  4PS7niVvIybq4KFGLDcy6D  2017.0  2010.0
#
# [1897 rows x 22 columns]

# %%
# Check the number of songs in each category 
df['decade'].value_counts().sort_index(ascending=True)
# Out:
# 1960.0    247
# 1970.0    166
# 1980.0    220
# 1990.0    283
# 2000.0    453
# 2010.0    365
# 2020.0    153
# Name: decade, dtype: int64

# %% [markdown]
# There is very little data for 1950s and 1940s so we can remove that from the data.

# %%
# Remove the decades 1950 and 1940 from the data 
df = df[(df['decade'] != 1940) & (df['decade'] != 1950)]
df.shape
# Out:
# (1887, 22)

# %%
# Plot the decade wise esong counts 
df['decade'].value_counts().sort_index(ascending=True).plot(kind='bar', )
# Out:
# <AxesSubplot:>

# %%
# Create a dataframe with the decade wise data
decade_wise_data = (
    df.groupby(["decade"])
    .agg(
        {
            "popularity": "mean",
            "danceability": "mean",
            "acousticness": "mean",
            "energy": "mean",
            "loudness": "mean",
            "speechiness": "mean",
            "valence": "mean",
            "tempo": "mean",
            "time_signature": "mean",
            "mode": "mean",
        }
    )
    .reset_index()
)
decade_wise_data
# Out:
#    decade  popularity  danceability  acousticness    energy   loudness  \
# 0  1960.0   24.684211      0.470332      0.895984  0.472692 -10.237000
# 1  1970.0   21.222892      0.448536      0.800000  0.519331  -9.829169
# 2  1980.0   37.927273      0.503118      0.649983  0.565470  -9.837691
# 3  1990.0   44.445230      0.576640      0.481292  0.595647 -11.064389
# 4  2000.0   49.028698      0.649448      0.305977  0.681386  -7.980609
# 5  2010.0   36.208219      0.611874      0.396002  0.666252  -7.487499
# 6  2020.0   58.228758      0.626209      0.482247  0.555000  -7.958405
#
#    speechiness   valence       tempo  time_signature      mode
# 0     0.070979  0.653656  111.418239        3.797571  0.688259
# 1     0.100990  0.581602  110.961289        3.795181  0.644578
# 2     0.069704  0.621176  115.179477        3.895455  0.572727
# 3     0.058888  0.680965  117.650095        3.911661  0.494700
# 4     0.072127  0.632962  115.015132        3.969095  0.615894
# 5     0.070099  0.621488  116.847077        3.882192  0.594521
# 6     0.065522  0.455584  114.275778        3.882353  0.705882

# %%
# Save the decade wise charachterstics 
decade_wise_data.to_csv('../data/decade_wise_song_features.csv', index=False)

# %% [markdown]
# ## Data Visualisation of the audio features

# %% [markdown]
# ## Cluster Analysis
